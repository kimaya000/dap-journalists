# %%
import pandas as pd
data_j=pd.read_csv("/Users/kimayashringarpure/Downloads/cpjdatabase.csv",  encoding_errors="ignore")

# %%
data_j.columns
data_j=data_j.drop(['Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
       'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)

# %%
data_j
# Out:
#                                                    Date  \
# 0                                              01/01/92
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# ...                                                 ...
# 1874  on an unknown date (death disclosed February 2...
# 1875                                        summer 1993
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                             Name         Sex Country Killed  \
# 0             Kladoumbaye Maxime        Male           Chad
# 1               Ram Singh Biling        Male          India
# 2                   Mustafa Jeha        Male        Lebanon
# ...

# %%
data_j=data_j.dropna(subset = ['Job', 'Organization', 'Coverage'])

# %%
print(data_j)
# Out:
#                                                    Date  \
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# 5                                               2/24/92
# ...                                                 ...
# 1873                                 October 5- 6, 2017
# 1874  on an unknown date (death disclosed February 2...
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                              Name   Sex Country Killed  \
# 1                Ram Singh Biling  Male          India
# 2                    Mustafa Jeha  Male        Lebanon
# 3                      Paul Jenks  Male        Croatia
# 4                    Halit Gungen  Male         Turkey
# ...

# %%
data_j.fillna("Information NA", inplace = True)
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2816341444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j.fillna("Information NA", inplace = True)

# %%
data_j
# Out:
#                                                    Date  \
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# 5                                               2/24/92
# ...                                                 ...
# 1873                                 October 5- 6, 2017
# 1874  on an unknown date (death disclosed February 2...
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                              Name   Sex Country Killed  \
# 1                Ram Singh Biling  Male          India
# 2                    Mustafa Jeha  Male        Lebanon
# 3                      Paul Jenks  Male        Croatia
# 4                    Halit Gungen  Male         Turkey
# ...

# %%
data_j["Sex"]=data_j["Sex"].replace("Sex", "Information NA")
data_j["Sex"]=data_j["Sex"].replace("na", "Information NA")
data_j["Sex"].describe()
data_j["Local/Foreign"]=data_j["Local/Foreign"].replace("Unknown Fire", "Information NA")
data_j["Local/Foreign"]=data_j["Local/Foreign"].replace("na", "Information NA")
data_j["Local/Foreign"]=data_j["Local/Foreign"].replace("Local/Foreign", "Information NA")
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2158085434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j["Sex"]=data_j["Sex"].replace("Sex", "Information NA")
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2158085434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j["Sex"]=data_j["Sex"].replace("na", "Information NA")
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2158085434.py:4: SettingWithCopyWarning:
# ...

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  
import pandas as pd  
#loading the dataset 'tips'  

#plotting the graph  
sns.countplot(x='Sex',data=data_j)  
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  
import pandas as pd  
#loading the dataset 'tips'  

#plotting the graph  
sns.countplot(x='Medium',data=data_j)  
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  
import pandas as pd  
#loading the dataset 'tips'  

#plotting the graph  
sns.countplot(x='Type of Death',data=data_j)  
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.xticks(rotation=90, fontsize=5)

plot1=sns.histplot(binwidth=0.5, x="Country Killed", hue="Sex", data=data_j, stat="count", multiple="stack")
fig = plot1.get_figure()
fig.savefig("/Users/kimayashringarpure/Downloads/out.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.xticks(rotation=90, fontsize=15)

plot1=sns.histplot(binwidth=0.5, x="Local/Foreign", hue="Sex", data=data_j, stat="count", multiple="stack")
fig = plot1.get_figure()
fig.savefig("/Users/kimayashringarpure/Downloads/plot1.png")

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  
import pandas as pd  
#loading the dataset 'tips'  

#plotting the graph  
sns.countplot(x='Medium',data=data_j)  
plt.xticks(rotation=90)
plt.show()

# %%
medium_data=data_j['Medium'].str.get_dummies(sep=',')
medium_data['Internet']=medium_data['Internet']+medium_data[' Internet']+medium_data[' Internet Reporter']
medium_data=medium_data.drop([' Internet Reporter',' Internet'], axis=1)
medium_data['Internet'].sum()
medium_data['Print']=medium_data['Print']+medium_data[' Print Reporter']
medium_data=medium_data.drop(' Print Reporter', axis=1)
medium_data['Radio']+=medium_data[' Radio']
medium_data=medium_data.drop(' Radio', axis=1)
medium_data['Television']+=medium_data[' Television']
medium_data['Information NA']=medium_data['na']+ medium_data['Medium']
medium_data=medium_data.drop(['na', 'Medium', ' Television'], axis=1)

# %%
medium_data.columns
internet=medium_data['Internet'].sum()
radio=medium_data['Radio'].sum()
tv=medium_data['Television'].sum()
pg=medium_data['Photographer'].sum()
prints=medium_data['Print'].sum()
Na=medium_data['Information NA'].sum()

# %%
df = pd.DataFrame({
    'Medium': ['Internet', 'Radio', 'Television','Photographer', 'Print', 'Information NA' ],
    'Weight': [internet, radio, tv, pg, prints, Na],})
df.plot.bar(x='Medium', y='Weight', rot=0)
# Out:
# <AxesSubplot:xlabel='Medium'>

# %%
data_j['Job'].unique()
# Out:
# array(['Print Reporter', 'Columnist', 'Photographer', 'Editor',
#        'Broadcast', 'Producer', 'Editor, Publisher',
#        'Photographer, Print Reporter', 'Columnist, Publisher',
#        'Broadcast, Print Reporter', 'Camera Operator', 'Publisher',
#        'Technician', 'Broadcast, Columnist', 'Editor, Print Reporter',
#        'Broadcast, Editor', 'Camera Operator, Photographer',
#        'Columnist, Editor', 'Broadcast, Photographer',
#        'Columnist, Producer', 'Broadcast, Camera Operator',
#        'Columnist, Print Reporter', 'Print Reporter, Publisher',
#        'Internet Reporter', 'Broadcast, Producer',
#        'Camera Operator, Internet Reporter, Producer',
#        'Columnist, Editor, Producer', 'Editor, Producer',
#        'Broadcast, Editor, Internet Reporter, Print Reporter',
#        'Internet Reporter, Print Reporter', 'Columnist, Photographer',
#        'Broadcast, Internet Reporter', 'Broadcast, Technician',
# ...

# %%
job_data=data_j['Job'].str.get_dummies(sep=', ')
job_data.columns
# Out:
# Index(['Broadcast', 'Broadcast Reporter', 'Broadcast reporter',
#        'Camera Operator', 'Columnist', 'Columnist / Commentator',
#        'Columnist/Commentator', 'Editor', 'Internet', 'Internet Reporter',
#        'Job', 'Photographer', 'Print', 'Print Reporter', 'Producer',
#        'Publisher', 'Publisher / Owner', 'Publisher/Owner', 'Technician',
#        'na'],
#       dtype='object')

# %%
job_data['Broadcast Reporter']+=job_data['Broadcast']+job_data['Broadcast reporter']
job_data['Columnist/Commentator']+=job_data['Columnist / Commentator']+job_data['Columnist']
job_data['Internet Reporter']+=job_data['Internet']
job_data['Print Reporter']+=job_data['Print']
job_data['Publisher/Owner']+=job_data['Publisher / Owner']+job_data['Publisher']
job_data['Information NA']=job_data['Job']+job_data['na']
job_data=job_data.drop(['Broadcast', 'Broadcast reporter', 'Columnist / Commentator', 'Columnist', 'Internet', 
                        'Print', 'Publisher / Owner', 'Publisher', 'Job', 'na' ], axis=1)

# %%
job_data.columns
# Out:
# Index(['Broadcast Reporter', 'Camera Operator', 'Columnist/Commentator',
#        'Editor', 'Internet Reporter', 'Photographer', 'Print Reporter',
#        'Producer', 'Publisher/Owner', 'Technician', 'Information NA'],
#       dtype='object')

# %%
df1=pd.DataFrame(job_data.sum())
df1.index
type_data=data_j['Type of Death']
type_data.unique()

type_data=type_data.replace(['Yes', 'No', 'na', 'Unknown', 'Type of Death'], 'Information NA')
type_data.unique()
type_data
# Out:
# 1           Dangerous Assignment
# 2                         Murder
# 3       Crossfire/Combat-Related
# 4                         Murder
# 5                         Murder
#                   ...
# 1873                      Murder
# 1874        Dangerous Assignment
# 1876                      Murder
# 1877        Dangerous Assignment
# 1878        Dangerous Assignment
# Name: Type of Death, Length: 1272, dtype: object

# %%
'''9. Circumstances of Death:
a. Incident Analysis
- Explore the circumstances surrounding the deaths (source of fire, type of death).
- Identify patterns or trends in the types of incidents.
'''
data_j.columns
type(type_data)
df2=pd.DataFrame(type_data)
dang_assgn=int(df2[df2['Type of Death']=='Dangerous Assignment'].count())
murder=int(df2[df2['Type of Death']=='Murder'].count())
cross=int(df2[df2['Type of Death']=='Crossfire/Combat-Related'].count())
nam=int(df2[df2['Type of Death']=='Information NA'].count())
crossfir=int(df2[df2['Type of Death']=='Crossfire'].count())
sus=int(df2[df2['Type of Death']=='Suspected Source of Fire:'].count())

data_j['Type of Death']=type_data
data_j['Type of Death'].unique()
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/440849336.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Type of Death']=type_data
# array(['Dangerous Assignment', 'Murder', 'Crossfire/Combat-Related',
#        'Information NA', 'Crossfire', 'Suspected Source of Fire:'],
#       dtype=object)

# %%
typeofdeath= pd.DataFrame({
    'Type of Death': ['Dangerous Assignment', 'Murder', 'Crossfire/Combat-Related','Crossfire', 'Suspected Source of Fire', 'Information NA' ],
    'Count': [dang_assgn, murder, cross, crossfir, sus, nam]})

typeofdeath.plot.bar(x='Type of Death', y='Count')
# Out:
# <AxesSubplot:xlabel='Type of Death'>

# %%
threat.unique()
threat=threat.replace(['na'], 'Information NA')
threat=threat.replace(['Threatened'], 'Yes')
threat.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/3758243042.py in <module>
# ----> 1 threat.unique()
#       2 threat=threat.replace(['na'], 'Information NA')
#       3 threat=threat.replace(['Threatened'], 'Yes')
#       4 threat.unique()
#
# NameError: name 'threat' is not defined

# %%
threat=data_j['Threatened']
threat.unique()
threat=threat.replace(['na'], 'Information NA')
threat=threat.replace(['Threatened'], 'Yes')
threat.unique()

threat_df=pd.DataFrame(threat)
threat_df
yes_t=int(threat_df[threat_df['Threatened']=='Yes'].count())
no_t=int(threat_df[threat_df['Threatened']=='No'].count())
threatened= pd.DataFrame({
    'Threatened': ['Yes', 'No'],
    'Count': [yes_t, no_t]})
threatened.plot.bar(x='Threatened', y='Count')

data_j['Threatened']=threat
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2110496014.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Threatened']=threat

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.xticks(rotation=90, fontsize=10)

plot1=sns.histplot(binwidth=0.5, x="Type of Death", hue="Threatened", data=data_j, stat="count", multiple="stack")
fig = plot1.get_figure()
fig.savefig("/Users/kimayashringarpure/Downloads/out.png")

# %%
data_j.columns
# Out:
# Index(['Date', 'Name', 'Sex', 'Country Killed', 'Organization', 'Nationality',
#        'Medium', 'Job', 'Coverage', 'Freelance', 'Local/Foreign',
#        'Source of Fire', 'Type of Death', 'Impunity (for Murder)',
#        'Taken Captive', 'Threatened', 'Tortured'],
#       dtype='object')

# %%
job_data['Threatened']=threat

job_data
# Out:
#       Broadcast Reporter  Camera Operator  Columnist/Commentator  Editor  \
# 1                      0                0                      0       0
# 2                      0                0                      1       0
# 3                      0                0                      0       0
# 4                      0                0                      0       1
# 5                      0                0                      0       0
# ...                  ...              ...                    ...     ...
# 1873                   0                0                      0       0
# 1874                   0                0                      0       1
# 1876                   0                0                      1       1
# 1877                   1                0                      0       0
# 1878                   1                0                      0       0
#
#       Internet Reporter  Photographer  Print Reporter  Producer  \
# ...

# %%
cov_data=data_j['Coverage'].str.get_dummies(sep=', ')
cov_data.columns
# Out:
# Index(['Business', 'Corruption', 'Coverage', 'Crime', 'Culture',
#        'Human Rights', 'No', 'Politics', 'Sports', 'War', 'Yes', 'na'],
#       dtype='object')

# %%
cov_data['Information NA']=cov_data['No']+cov_data['Yes']+cov_data['na']+cov_data['Coverage']
cov_data=cov_data.drop(['Coverage', 'No', 'Yes', 'na'], axis=1)
cov_data
# Out:
#       Business  Corruption  Crime  Culture  Human Rights  Politics  Sports  \
# 1            0           1      0        0             1         1       0
# 2            0           0      0        0             0         1       0
# 3            0           0      0        0             0         0       0
# 4            0           1      0        0             1         1       0
# 5            0           1      0        0             0         1       0
# ...        ...         ...    ...      ...           ...       ...     ...
# 1873         0           0      1        1             0         0       0
# 1874         0           0      0        0             0         1       0
# 1876         0           1      0        0             1         1       0
# 1877         0           0      0        0             1         1       0
# 1878         0           0      0        0             1         1       0
#
#       War  Information NA
# 1       0               0
# ...

# %%
cov_data['Threatened']=threat

# %%
# Count the number of rows where Business is 1 and Threatened is 'Yes'
business_threats = cov_data[(cov_data['Business'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where Human Rights is 1 and Threatened is 'Yes'
human_rights_threats = cov_data[(cov_data['Human Rights'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where Politics is 1 and Threatened is 'Yes'
politics_threats = cov_data[(cov_data['Politics'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]
# Count the number of rows where Sports is 1 and Threatened is 'Yes'
sports_threats = cov_data[(cov_data['Sports'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where War is 1 and Threatened is 'Yes'
war_threats = cov_data[(cov_data['War'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where Crime is 1 and Threatened is 'Yes'
crime_threats = cov_data[(cov_data['Crime'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where Corruption is 1 and Threatened is 'Yes'
corruption_threats = cov_data[(cov_data['Corruption'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

# Count the number of rows where Culture is 1 and Threatened is 'Yes'
culture_threats = cov_data[(cov_data['Culture'] == 1) & (cov_data['Threatened'] == 'Yes')].shape[0]

job_counts_df = pd.DataFrame({
    'Job': ['Business', 'Human Rights', 'Politics', 'Sports', 'War', 'Crime', 'Corruption', 'Culture'],
    'Threatened_Count': [business_threats, human_rights_threats, politics_threats,
                         sports_threats, war_threats, crime_threats, corruption_threats, culture_threats]
})

job_counts_df.plot.bar(x='Job', y='Threatened_Count')
# Out:
# <AxesSubplot:xlabel='Job'>

# %%
fire_data=data_j['Source of Fire'].str.get_dummies(sep=', ')
fire_data.columns
fire_data['Information NA']=fire_data['na']+fire_data['Source of Fire']+fire_data['Unknown Fire']
fire_data=fire_data.drop(['Unknown Fire', 'na', 'Unknown Fire'], axis=1)
fire_data['Threatened']=threat
fire_data.columns
# Out:
# Index(['Criminal Group', 'Crossfire/Combat-Related', 'Dangerous Assignment',
#        'Government Officials', 'Local Residents', 'Military Officials',
#        'Mob Violence', 'Murder', 'Paramilitary Group', 'Political Group',
#        'Source of Fire', 'Information NA', 'Threatened'],
#       dtype='object')

# %%
# Calculate counts for each source of fire
criminal_group_threats = fire_data[(fire_data['Criminal Group'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
combat_related_threats = fire_data[(fire_data['Crossfire/Combat-Related'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
dangerous_assignment_threats = fire_data[(fire_data['Dangerous Assignment'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
government_officials_threats = fire_data[(fire_data['Government Officials'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
local_residents_threats = fire_data[(fire_data['Local Residents'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
military_officials_threats = fire_data[(fire_data['Military Officials'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
mob_violence_threats = fire_data[(fire_data['Mob Violence'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
murder_threats = fire_data[(fire_data['Murder'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
paramilitary_group_threats = fire_data[(fire_data['Paramilitary Group'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
political_group_threats = fire_data[(fire_data['Political Group'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
source_of_fire_threats = fire_data[(fire_data['Source of Fire'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]
information_na_threats = fire_data[(fire_data['Information NA'] == 1) & (fire_data['Threatened'] == 'Yes')].shape[0]

# Create a new DataFrame
source_of_fire_counts_df = pd.DataFrame({
    'Source of Fire': ['Criminal Group', 'Crossfire/Combat-Related', 'Dangerous Assignment',
                        'Government Officials', 'Local Residents', 'Military Officials',
                        'Mob Violence', 'Murder', 'Paramilitary Group', 'Political Group',
                        'Source of Fire', 'Information NA'],
    'Threatened_Count': [criminal_group_threats, combat_related_threats, dangerous_assignment_threats,
                        government_officials_threats, local_residents_threats, military_officials_threats,
                        mob_violence_threats, murder_threats, paramilitary_group_threats,
                        political_group_threats, source_of_fire_threats, information_na_threats]
})
source_of_fire_counts_df.plot.bar(x='Source of Fire', y='Threatened_Count')
# Out:
# <AxesSubplot:xlabel='Source of Fire'>

# %%
impunity=data_j['Impunity (for Murder)']
impunity=impunity.replace(['na', 'Impunity (for Murder)'], 'Information NA' )
fire_data['Impunity']=impunity
impunity.unique()
data_j['Impunity (for Murder)']=impunity
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/3683571710.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Impunity (for Murder)']=impunity

# %%
data_j
plot5=sns.histplot(binwidth=0.5, x="Source of Fire", hue="Type of Death", data=data_j, stat="count", multiple="stack")
plt.xticks(rotation=90)
plot5
# Out:
# <AxesSubplot:xlabel='Source of Fire', ylabel='Count'>

# %%
data_j['Threatened']=threat
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/3701822351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Threatened']=threat

# %%
data_j.groupby('Impunity (for Murder)').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
data_j.groupby('Threatened').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
source_fire=fire_data.iloc[:, :11].sum()
source_fire.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plot5=sns.histplot(binwidth=0.5, x="Country Killed", hue="Impunity (for Murder)", data=data_j, stat="count", multiple="stack")
plt.xticks(rotation=90, size=5)
plot5
# Out:
# <AxesSubplot:xlabel='Country Killed', ylabel='Count'>

# %%
data_j
# Out:
#                                                    Date  \
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# 5                                               2/24/92
# ...                                                 ...
# 1873                                 October 5- 6, 2017
# 1874  on an unknown date (death disclosed February 2...
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                              Name   Sex Country Killed  \
# 1                Ram Singh Biling  Male          India
# 2                    Mustafa Jeha  Male        Lebanon
# 3                      Paul Jenks  Male        Croatia
# 4                    Halit Gungen  Male         Turkey
# ...

# %%
data_j['Taken Captive']=data_j['Taken Captive'].replace(['na', 'Taken Captive'], 'Information NA')
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2015478837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Taken Captive']=data_j['Taken Captive'].replace(['na', 'Taken Captive'], 'Information NA')

# %%
plot5=sns.histplot(binwidth=0.5, x="Sex", hue="Taken Captive", data=data_j, stat="count", multiple="stack")
plt.xticks(rotation=90)
plot5
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
plot5=sns.histplot(binwidth=0.5, x="Local/Foreign", hue="Taken Captive", data=data_j, stat="count", multiple="stack")
plt.xticks(rotation=90)
plot5
# Out:
# <AxesSubplot:xlabel='Local/Foreign', ylabel='Count'>

# %%
data_j['Tortured']=data_j['Tortured'].replace(['na', 'Tortured'], 'Information NA' )
# Out:
# /var/folders/nv/gdb08pbs7155qxq1brb_hwnw0000gn/T/ipykernel_47942/2299387246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_j['Tortured']=data_j['Tortured'].replace(['na', 'Tortured'], 'Information NA' )

# %%
plot5=sns.histplot(binwidth=0.5, x="Sex", hue="Tortured", data=data_j, stat="count", multiple="stack")
plt.xticks(rotation=90)
plot5
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
jobsum=job_data.iloc[:,0:11].sum()
jobsum.plot.bar(color="Green")
# Out:
# <AxesSubplot:>

# %%
data_j.groupby('Tortured').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
data_j
# Out:
#                                                    Date  \
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# 5                                               2/24/92
# ...                                                 ...
# 1873                                 October 5- 6, 2017
# 1874  on an unknown date (death disclosed February 2...
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                              Name   Sex Country Killed  \
# 1                Ram Singh Biling  Male          India
# 2                    Mustafa Jeha  Male        Lebanon
# 3                      Paul Jenks  Male        Croatia
# 4                    Halit Gungen  Male         Turkey
# ...

# %%
# Calculate counts for each source of fire
criminal_group_impunity = fire_data[(fire_data['Criminal Group'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
combat_related_impunity = fire_data[(fire_data['Crossfire/Combat-Related'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
dangerous_assignment_impunity = fire_data[(fire_data['Dangerous Assignment'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
government_officials_impunity = fire_data[(fire_data['Government Officials'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
local_residents_impunity = fire_data[(fire_data['Local Residents'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
military_officials_impunity = fire_data[(fire_data['Military Officials'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
mob_violence_impunity = fire_data[(fire_data['Mob Violence'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
murder_impunity = fire_data[(fire_data['Murder'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
paramilitary_group_impunity = fire_data[(fire_data['Paramilitary Group'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
political_group_impunity = fire_data[(fire_data['Political Group'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
source_of_fire_impunity = fire_data[(fire_data['Source of Fire'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]
information_na_impunity = fire_data[(fire_data['Information NA'] == 1) & (fire_data['Impunity'] == 'Yes')].shape[0]

# Create a new DataFrame
source_of_fire_counts_impunity_df = pd.DataFrame({
    'Source of Fire': ['Criminal Group', 'Crossfire/Combat-Related', 'Dangerous Assignment',
                        'Government Officials', 'Local Residents', 'Military Officials',
                        'Mob Violence', 'Murder', 'Paramilitary Group', 'Political Group',
                        'Source of Fire', 'Information NA'],
    'Impunity_Count': [criminal_group_impunity, combat_related_impunity, dangerous_assignment_impunity,
                        government_officials_impunity, local_residents_impunity, military_officials_impunity,
                        mob_violence_impunity, murder_impunity, paramilitary_group_impunity,
                        political_group_impunity, source_of_fire_impunity, information_na_impunity]
})
source_of_fire_counts_impunity_df.plot.bar(color='Yellow', x='Source of Fire', y= 'Impunity_Count')
# Out:
# <AxesSubplot:xlabel='Source of Fire'>

# %%
fire_data
# Out:
#       Criminal Group  Crossfire/Combat-Related  Dangerous Assignment  \
# 1                  0                         0                     0
# 2                  0                         0                     0
# 3                  0                         0                     0
# 4                  0                         0                     0
# 5                  0                         0                     0
# ...              ...                       ...                   ...
# 1873               1                         0                     0
# 1874               0                         0                     0
# 1876               0                         0                     0
# 1877               0                         0                     0
# 1878               0                         0                     0
#
#       Government Officials  Local Residents  Military Officials  Mob Violence  \
# ...

# %%
fire_data['Impunity'].unique()
fire_data['Impunity']=fire_data['Impunity'].replace('Complete Impunity', 'Yes')

# %%
data_j['']
# Out:
#                                                    Date  \
# 1                                              01/03/92
# 2                                               1/15/92
# 3                                               1/17/92
# 4                                              02/09/92
# 5                                               2/24/92
# ...                                                 ...
# 1873                                 October 5- 6, 2017
# 1874  on an unknown date (death disclosed February 2...
# 1876                                            Unknown
# 1877                                            Unknown
# 1878                                            Unknown
#
#                              Name   Sex Country Killed  \
# 1                Ram Singh Biling  Male          India
# 2                    Mustafa Jeha  Male        Lebanon
# 3                      Paul Jenks  Male        Croatia
# 4                    Halit Gungen  Male         Turkey
# ...
